# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Data ingestion & inspection

# %%
sunspots = pd.read_csv('ISSN_D_tot.csv')
sunspots.head()
# Out:
#    1818  01  01.1  1818.004   -1  1
# 0  1818   1     2  1818.007   -1  1
# 1  1818   1     3  1818.010   -1  1
# 2  1818   1     4  1818.012   -1  1
# 3  1818   1     5  1818.015   -1  1
# 4  1818   1     6  1818.018   -1  1

# %%
sunspots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71860 entries, 0 to 71859
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   1818      71860 non-null  int64
#  1   01        71860 non-null  int64
#  2   01.1      71860 non-null  int64
#  3   1818.004  71860 non-null  float64
#  4    -1       71860 non-null  int64
#  5   1         71860 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 3.3 MB

# %%
col_names = ['year', 'month', 'day', 'dec_date','sunspots', 'definite']
sunspots = pd.read_csv('ISSN_D_tot.csv', 
                       header=None, 
                       names=col_names, 
                       na_values={'sunspots':[' -1']}, 
                       parse_dates=[[0, 1, 2]])
sunspots.head()
# Out:
#   year_month_day  dec_date  sunspots  definite
# 0     1818-01-01  1818.004       NaN         1
# 1     1818-01-02  1818.007       NaN         1
# 2     1818-01-03  1818.010       NaN         1
# 3     1818-01-04  1818.012       NaN         1
# 4     1818-01-05  1818.015       NaN         1

# %%
sunspots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71861 entries, 0 to 71860
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year_month_day  71861 non-null  datetime64[ns]
#  1   dec_date        71861 non-null  float64
#  2   sunspots        68614 non-null  float64
#  3   definite        71861 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 2.2 MB

# %%
sunspots.index = sunspots['year_month_day']
sunspots.index.name = 'date'
sunspots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 71861 entries, 1818-01-01 to 2014-09-30
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year_month_day  71861 non-null  datetime64[ns]
#  1   dec_date        71861 non-null  float64
#  2   sunspots        68614 non-null  float64
#  3   definite        71861 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 2.7 MB

# %%
aapl = pd.read_csv('aapl.csv', index_col='Date', parse_dates=True)
aapl.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
# 2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6081 entries, 2008-10-14 to 1984-09-07
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6081 non-null   float64
#  1   High       6081 non-null   float64
#  2   Low        6081 non-null   float64
#  3   Close      6081 non-null   float64
#  4   Volume     6081 non-null   int64
#  5   Adj Close  6081 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 332.6 KB

# %%
aapl.plot();
plt.yscale('log')
plt.savefig('aapl.png')

# %%
aapl['Open'].plot(color='b', style='-', legend=True);
aapl['Close'].plot(color='r', style='.', legend=True);

# %%
aapl.plot(subplots = True);

# %% [markdown]
# ## 2. Exploratory data analysis

# %%
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70     US  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70     US          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70     US         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70     US              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70     US                ford torino

# %%
df.plot(kind='scatter', x='hp', y='mpg');

# Add the title
plt.title('Fuel efficiency vs Horse-power')

# Add the x-axis label
plt.xlabel('Horse-power')

# Add the y-axis label
plt.ylabel('Fuel efficiency (mpg)')
# Out:
# Text(0, 0.5, 'Fuel efficiency (mpg)')

# %%
# Make a list of the column names to be plotted: cols
cols = ['weight','mpg']

# Generate the box plots
df[cols].plot(kind = 'box', subplots = True);

# %%
titanic = pd.read_csv('titanic.csv')
# Display the box plots on 3 separate rows and 1 column
fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True)

# Generate a box plot of the fare prices for the First passenger class
titanic.loc[titanic['pclass'] == 1].plot(ax=axes[0], y='fare', kind='box')

# Generate a box plot of the fare prices for the Second passenger class
titanic.loc[titanic['pclass'] == 2].plot(ax=axes[1], y='fare', kind='box')

# Generate a box plot of the fare prices for the Third passenger class
titanic.loc[titanic['pclass'] == 3].plot(ax=axes[2], y='fare', kind='box')

# %% [markdown]
# ## 3. Time series in pandas

# %% [markdown]
# ### Creating and using a DatetimeIndex

# %%
df = pd.read_csv('weather_data_austin_2010.csv')

# Prepare a format string: time_format
time_format ='%Y-%m-%d %H:%M'

# Convert date_list into a datetime object: my_datetimes
df['Date'] = pd.to_datetime(df['Date'], format=time_format)  

df.index = df['Date']

df.drop('Date', axis = 1, inplace = True)

df.head()
# Out:
#                      Temperature  DewPoint  Pressure
# Date
# 2010-01-01 00:00:00         46.2      37.5       1.0
# 2010-01-01 01:00:00         44.6      37.1       1.0
# 2010-01-01 02:00:00         44.1      36.9       1.0
# 2010-01-01 03:00:00         43.8      36.9       1.0
# 2010-01-01 04:00:00         43.5      36.8       1.0

# %%
# Plot the summer data
df.Temperature['2010-Jun':'2010-Aug'].plot()
plt.show()
plt.clf()
# Plot the one week data
df.Temperature['2010-06-10':'2010-06-17'].plot()
plt.show()
plt.clf()

# %%
ts0 = df['Temperature']
ts0.head()
# Out:
# Date
# 2010-01-01 00:00:00    46.2
# 2010-01-01 01:00:00    44.6
# 2010-01-01 02:00:00    44.1
# 2010-01-01 03:00:00    43.8
# 2010-01-01 04:00:00    43.5
# Name: Temperature, dtype: float64

# %% [markdown]
# ### Partial string indexing and slicing

# %%
# Extract the hour from 9pm to 10pm on '2010-10-11': ts1
ts1 = ts0.loc['2010-10-11 21:00:00':'2010-10-11 22:00:00']

# Extract '2010-07-04' from ts0: ts2
ts2 = ts0.loc['2010-07-04']

# Extract data from '2010-12-15' to '2010-12-31': ts3
ts3 = ts0.loc['2010-12-15':'2010-12-31']

ts1, ts2, ts3
# Out:
# (Date
#  2010-10-11 21:00:00    69.0
#  2010-10-11 22:00:00    67.7
#  Name: Temperature, dtype: float64,
#  Date
#  2010-07-04 00:00:00    77.6
#  2010-07-04 01:00:00    76.3
#  2010-07-04 02:00:00    75.5
#  2010-07-04 03:00:00    74.9
#  2010-07-04 04:00:00    74.6
#  2010-07-04 05:00:00    74.2
#  2010-07-04 06:00:00    74.4
#  2010-07-04 07:00:00    76.0
#  2010-07-04 08:00:00    79.0
#  2010-07-04 09:00:00    81.8
#  2010-07-04 10:00:00    84.6
#  2010-07-04 11:00:00    86.8
#  2010-07-04 12:00:00    88.9
#  2010-07-04 13:00:00    90.1
#  2010-07-04 14:00:00    91.1
#  2010-07-04 15:00:00    91.6
#  2010-07-04 16:00:00    91.5
#  2010-07-04 17:00:00    90.7
#  2010-07-04 18:00:00    89.5
#  2010-07-04 19:00:00    87.3
#  2010-07-04 20:00:00    84.0
#  2010-07-04 21:00:00    81.8
#  2010-07-04 22:00:00    80.0
#  2010-07-04 23:00:00    78.5
#  Name: Temperature, dtype: float64,
#  Date
#  2010-12-15 00:00:00    48.0
#  2010-12-15 01:00:00    47.2
#  2010-12-15 02:00:00    46.5
#  2010-12-15 03:00:00    46.0
#  2010-12-15 04:00:00    45.6
#                         ...
#  2010-12-31 19:00:00    51.1
#  2010-12-31 20:00:00    49.0
#  2010-12-31 21:00:00    47.9
#  2010-12-31 22:00:00    46.9
#  2010-12-31 23:00:00    46.2
#  Name: Temperature, Length: 408, dtype: float64)

# %% [markdown]
# ### Reindexing the Index

# %%
# Reindex with fill method, using forward fill: ts4
ts4 = ts2.reindex(ts1.index, method = 'ffill')
ts4
# Out:
# Date
# 2010-10-11 21:00:00    78.5
# 2010-10-11 22:00:00    78.5
# Name: Temperature, dtype: float64

# %% [markdown]
# ### Resampling and frequency

# %%
# Downsample to 6 hour data and aggregate by mean: df1
df1 = df['Temperature'].resample('6h').mean()

# Downsample to daily data and count the number of data points: df2
df2 = df['Temperature'].resample('D').count()
df1, df2
# Out:
# (Date
#  2010-01-01 00:00:00    44.200000
#  2010-01-01 06:00:00    45.933333
#  2010-01-01 12:00:00    57.766667
#  2010-01-01 18:00:00    49.450000
#  2010-01-02 00:00:00    44.516667
#                           ...
#  2010-12-30 18:00:00    49.150000
#  2010-12-31 00:00:00    44.133333
#  2010-12-31 06:00:00    45.916667
#  2010-12-31 12:00:00    57.500000
#  2010-12-31 18:00:00    49.233333
#  Freq: 6H, Name: Temperature, Length: 1460, dtype: float64,
#  Date
#  2010-01-01    24
#  2010-01-02    24
#  2010-01-03    24
#  2010-01-04    24
#  2010-01-05    24
#                ..
#  2010-12-27    24
#  2010-12-28    24
#  2010-12-29    24
#  2010-12-30    24
#  2010-12-31    24
#  Freq: D, Name: Temperature, Length: 365, dtype: int64)

# %% [markdown]
# ### Separating and resampling

# %%
# Extract temperature data for August: august
august = df['Temperature'].loc['2010-August']

# Downsample to obtain only the daily highest temperatures in August: august_highs
august_highs = august.resample('D').max()

# Extract temperature data for February: february
february = df['Temperature'].loc['2010-February']

# Downsample to obtain the daily lowest temperatures in February: february_lows
february_lows = february.resample('D').min()
august_highs, february_lows
# Out:
# (Date
#  2010-08-01    95.0
#  2010-08-02    95.0
#  2010-08-03    95.1
#  2010-08-04    95.1
#  2010-08-05    95.1
#  2010-08-06    95.2
#  2010-08-07    95.3
#  2010-08-08    95.2
#  2010-08-09    95.2
#  2010-08-10    95.1
#  2010-08-11    95.0
#  2010-08-12    94.9
#  2010-08-13    95.0
#  2010-08-14    94.9
#  2010-08-15    94.7
#  2010-08-16    94.7
#  2010-08-17    94.8
#  2010-08-18    94.8
#  2010-08-19    94.8
#  2010-08-20    94.8
#  2010-08-21    94.7
#  2010-08-22    94.6
#  2010-08-23    94.5
#  2010-08-24    94.3
#  2010-08-25    94.1
#  2010-08-26    94.0
#  2010-08-27    93.7
#  2010-08-28    93.5
#  2010-08-29    93.3
#  2010-08-30    93.3
#  2010-08-31    93.1
#  Freq: D, Name: Temperature, dtype: float64,
#  Date
#  2010-02-01    43.8
#  2010-02-02    44.3
#  2010-02-03    44.6
#  2010-02-04    44.5
#  2010-02-05    44.3
#  2010-02-06    44.1
#  2010-02-07    44.3
#  2010-02-08    44.7
#  2010-02-09    44.7
#  2010-02-10    44.9
#  2010-02-11    45.2
#  2010-02-12    45.5
#  2010-02-13    46.0
#  2010-02-14    46.6
#  2010-02-15    46.9
#  2010-02-16    47.1
#  2010-02-17    47.2
#  2010-02-18    47.2
#  2010-02-19    47.4
#  2010-02-20    47.7
#  2010-02-21    47.6
#  2010-02-22    47.7
#  2010-02-23    47.7
#  2010-02-24    48.1
#  2010-02-25    48.4
#  2010-02-26    48.5
#  2010-02-27    48.6
#  2010-02-28    48.6
#  Freq: D, Name: Temperature, dtype: float64)

# %% [markdown]
# ### Rolling mean and frequency

# %%
# Extract data from 2010-Aug-01 to 2010-Aug-15: unsmoothed
unsmoothed = df['Temperature']['2010-Aug-01':'2010-Aug-15']

# Apply a rolling mean with a 24 hour window: smoothed
smoothed = unsmoothed.rolling(window = 24).mean()

# Create a new DataFrame with columns smoothed and unsmoothed: august
august = pd.DataFrame({'smoothed':smoothed, 'unsmoothed':unsmoothed})

# Plot both smoothed and unsmoothed data using august.plot().
august.plot()
plt.show()

# %% [markdown]
# ### Resample and roll with it

# %%
# Extract the August 2010 data: august
august = df['Temperature']['2010-August']

# Resample to daily data, aggregating by max: daily_highs
daily_highs = august.resample('D').max()

# Use a rolling 7-day window with method chaining to smooth the daily high temperatures in August
daily_highs_smoothed = daily_highs.rolling(window = 7).mean()
print(daily_highs_smoothed)
# Out:
# Date
# 2010-08-01          NaN
# 2010-08-02          NaN
# 2010-08-03          NaN
# 2010-08-04          NaN
# 2010-08-05          NaN
# 2010-08-06          NaN
# 2010-08-07    95.114286
# 2010-08-08    95.142857
# 2010-08-09    95.171429
# 2010-08-10    95.171429
# 2010-08-11    95.157143
# 2010-08-12    95.128571
# 2010-08-13    95.100000
# 2010-08-14    95.042857
# 2010-08-15    94.971429
# 2010-08-16    94.900000
# 2010-08-17    94.857143
# 2010-08-18    94.828571
# 2010-08-19    94.814286
# 2010-08-20    94.785714
# 2010-08-21    94.757143
# 2010-08-22    94.742857
# 2010-08-23    94.714286
# 2010-08-24    94.642857
# 2010-08-25    94.542857
# 2010-08-26    94.428571
# 2010-08-27    94.271429
# 2010-08-28    94.100000
# 2010-08-29    93.914286
# 2010-08-30    93.742857
# 2010-08-31    93.571429
# Freq: D, Name: Temperature, dtype: float64

# %% [markdown]
# ### Missing values and interpolation

# %%
# Reset the index of ts2 to ts1, and then use linear interpolation to fill in the NaNs: ts2_interp
ts2_interp = ts2.reindex(ts1.index).interpolate(how = 'linear')

# Compute the absolute difference of ts1 and ts2_interp: differences 
differences = abs(ts1 -ts2_interp)

# Generate and print summary statistics of the differences
print(differences.describe())
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Temperature, dtype: float64

# %% [markdown]
# ### Method chaining and filtering

# %%
df = pd.read_csv('austin_airport_departure_data_2015_july.csv', header = 10, parse_dates = True, index_col = 'Date (MM/DD/YYYY)')
df['Date (MM/DD/YYYY)'] = df.index
df['Date (MM/DD/YYYY)'] = df['Date (MM/DD/YYYY)'].astype('str')
df.head()
# Out:
#                     Carrier Code  Flight Number Tail Number  \
# Date (MM/DD/YYYY)
# 2015-07-01                    WN          103.0      N8607M
# 2015-07-01                    WN          144.0      N8609A
# 2015-07-01                    WN          178.0      N646SW
# 2015-07-01                    WN          232.0      N204WN
# 2015-07-01                    WN          238.0      N233LV
#
#                   Destination Airport  Scheduled Departure Time  \
# Date (MM/DD/YYYY)
# 2015-07-01                         MDW                    06:30
# 2015-07-01                         SAN                    20:55
# 2015-07-01                         ELP                    20:30
# 2015-07-01                         ATL                    05:45
# 2015-07-01                         DAL                    12:30
#
#                   Actual Departure Time  Scheduled Elapsed Time(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                        06:52                            165.0
# 2015-07-01                        20:50                            170.0
# 2015-07-01                        20:45                             90.0
# 2015-07-01                        05:49                            135.0
# 2015-07-01                        12:34                             55.0
#
#                    Actual Elapsed Time(Minutes)  Departure Delay(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                                147.0                      22.0
# 2015-07-01                                158.0                      -5.0
# 2015-07-01                                 80.0                      15.0
# 2015-07-01                                137.0                       4.0
# 2015-07-01                                 48.0                       4.0
#
#                   Wheels-off Time  Taxi-out Time(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                  07:01                     9.0
# 2015-07-01                  21:03                    13.0
# 2015-07-01                  20:55                    10.0
# 2015-07-01                  06:01                    12.0
# 2015-07-01                  12:41                     7.0
#
#                    DelayCarrier(Minutes)  DelayWeather(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
#
#                    DelayNational Aviation System(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
#
#                    DelaySecurity(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                            0.0
# 2015-07-01                            0.0
# 2015-07-01                            0.0
# 2015-07-01                            0.0
# 2015-07-01                            0.0
#
#                    DelayLate Aircraft Arrival(Minutes)  Unnamed: 17  \
# Date (MM/DD/YYYY)
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN
#
#                   Date (MM/DD/YYYY)
# Date (MM/DD/YYYY)
# 2015-07-01               2015-07-01
# 2015-07-01               2015-07-01
# 2015-07-01               2015-07-01
# 2015-07-01               2015-07-01
# 2015-07-01               2015-07-01

# %%
# Strip extra whitespace from the column names: df.columns
df.columns = df.columns.str.strip()

# Extract data for which the destination airport is Dallas: dallas
dallas = df['Destination Airport'].str.contains('DAL')

# Compute the total number of Dallas departures each day: daily_departures
daily_departures = dallas.resample('D').sum()

# Generate the summary statistics for daily Dallas departures: stats
stats = daily_departures.describe()

# %%
stats
# Out:
# count    31.000000
# mean      9.322581
# std       1.989759
# min       3.000000
# 25%       9.500000
# 50%      10.000000
# 75%      10.000000
# max      11.000000
# dtype: float64

# %% [markdown]
# ### Time zones and conversion

# %%
# Build a Boolean mask to filter out all the 'LAX' departure flights: mask
mask = df['Destination Airport'] == 'LAX'

# Use the mask to subset the data: la
la = df[mask]

# Combine two columns of data to create a datetime series: times_tz_none 
times_tz_none = pd.to_datetime(la['Date (MM/DD/YYYY)'] + ' ' + la['Wheels-off Time'])

# Localize the time to US/Central: times_tz_central
times_tz_central = times_tz_none.dt.tz_localize('US/Central')


# Convert the datetimes from US/Central to US/Pacific
times_tz_pacific = times_tz_central.dt.tz_convert('US/Pacific')

# %%
times_tz_pacific.head()
# Out:
# Date (MM/DD/YYYY)
# 2015-07-01   2015-07-01 03:43:00-07:00
# 2015-07-01   2015-07-01 14:27:00-07:00
# 2015-07-02   2015-07-02 03:47:00-07:00
# 2015-07-02   2015-07-02 14:23:00-07:00
# 2015-07-03   2015-07-03 03:30:00-07:00
# dtype: datetime64[ns, US/Pacific]

# %% [markdown]
# ## 4. Case Study- Sunlight in Austin

# %%
columns = pd.read_csv('column_labels.txt')
df = pd.read_csv('NOAA_QCLCD_2011_hourly_13904.txt',header = None, names = columns)
list_to_drop = ['sky_conditionFlag', 'visibilityFlag', 'wx_and_obst_to_vision', 'wx_and_obst_to_visionFlag', 'dry_bulb_farenFlag', 'dry_bulb_celFlag', 'wet_bulb_farenFlag', 'wet_bulb_celFlag', 'dew_point_farenFlag', 'dew_point_celFlag', 'relative_humidityFlag', 'wind_speedFlag', 'wind_directionFlag', 'value_for_wind_character', 'value_for_wind_characterFlag', 'station_pressureFlag', 'pressure_tendencyFlag', 'pressure_tendency', 'presschange', 'presschangeFlag', 'sea_level_pressureFlag', 'hourly_precip', 'hourly_precipFlag', 'altimeter', 'record_type', 'altimeterFlag', 'junk']
df_dropped = df.drop(list_to_drop, axis = 'columns')
df_dropped.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a90f29668f93> in <module>
#       1 columns = pd.read_csv('column_labels.txt')
# ----> 2 df = pd.read_csv('NOAA_QCLCD_2011_hourly_13904.txt',header = None, names = columns)
#       3 list_to_drop = ['sky_conditionFlag', 'visibilityFlag', 'wx_and_obst_to_vision', 'wx_and_obst_to_visionFlag', 'dry_bulb_farenFlag', 'dry_bulb_celFlag', 'wet_bulb_farenFlag', 'wet_bulb_celFlag', 'dew_point_farenFlag', 'dew_point_celFlag', 'relative_humidityFlag', 'wind_speedFlag', 'wind_directionFlag', 'value_for_wind_character', 'value_for_wind_characterFlag', 'station_pressureFlag', 'pressure_tendencyFlag', 'pressure_tendency', 'presschange', 'presschangeFlag', 'sea_level_pressureFlag', 'hourly_precip', 'hourly_precipFlag', 'altimeter', 'record_type', 'altimeterFlag', 'junk']
#       4 df_dropped = df.drop(list_to_drop, axis = 'columns')
#       5 df_dropped.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     443
#     444     # Check for duplicates in names.
# --> 445     _validate_names(kwds.get("names", None))
#     446
#     447     # Create the parser.
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _validate_names(names)
#     411     if names is not None:
#     412         if len(names) != len(set(names)):
# --> 413             raise ValueError("Duplicate names are not allowed.")
#     414
#     415
#
# ValueError: Duplicate names are not allowed.

# %% [markdown]
# ### Cleaning and tidying datetime data

# %%
# Convert the date column to string: df_dropped['date']
df_dropped['date'] = df_dropped['date'].astype(str)

# Pad leading zeros to the Time column: df_dropped['Time']
df_dropped['Time'] = df_dropped['Time'].apply(lambda x:'{:0>4}'.format(x))

# Concatenate the new date and Time columns: date_string
date_string = df_dropped['date'] + df_dropped['Time']

# Convert the date_string Series to datetime: date_times
date_times = pd.to_datetime(date_string, format='%Y%m%d%H%M')

# Set the index to be the new date_times container: df_clean
df_clean = df_dropped.set_index(date_times)

# Print the output of df_clean.head()
df_clean.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-619fc7bfc199> in <module>
#       1 # Convert the date column to string: df_dropped['date']
# ----> 2 df_dropped['date'] = df_dropped['date'].astype(str)
#       3
#       4 # Pad leading zeros to the Time column: df_dropped['Time']
#       5 df_dropped['Time'] = df_dropped['Time'].apply(lambda x:'{:0>4}'.format(x))
#
# NameError: name 'df_dropped' is not defined

# %% [markdown]
# ### Cleaning the numeric columns

# %%
# Convert the dry_bulb_faren column to numeric values: df_clean['dry_bulb_faren']
df_clean['dry_bulb_faren'] = pd.to_numeric(df_clean['dry_bulb_faren'], errors= 'coerce')

# Convert the wind_speed and dew_point_faren columns to numeric values
df_clean['wind_speed'] = pd.to_numeric(df_clean['wind_speed'], errors= 'coerce')
df_clean['dew_point_faren'] = pd.to_numeric(df_clean['dew_point_faren'], errors= 'coerce')

# Print the transformed dry_bulb_faren temperature between 8 AM and 9 AM on June 20, 2011
df_clean.loc['2011-06-20 8:00:00':'2011-06-20 9:00:00', :].sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f94156f17852> in <module>
#       1 # Convert the dry_bulb_faren column to numeric values: df_clean['dry_bulb_faren']
# ----> 2 df_clean['dry_bulb_faren'] = pd.to_numeric(df_clean['dry_bulb_faren'], errors= 'coerce')
#       3
#       4 # Convert the wind_speed and dew_point_faren columns to numeric values
#       5 df_clean['wind_speed'] = pd.to_numeric(df_clean['wind_speed'], errors= 'coerce')
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# ### Signal min, max, median

# %%
# Print the median of the dry_bulb_faren column
print(df_clean['dry_bulb_faren'].median())

# Print the median of the dry_bulb_faren column for the time range '2011-Apr':'2011-Jun'
print(df_clean.loc['2011-Apr':'2011-Jun', 'dry_bulb_faren'].median())

# Print the median of the dry_bulb_faren column for the month of January
print(df_clean.loc['2011-Jan','dry_bulb_faren'].median())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-234ed2fe7eca> in <module>
#       1 # Print the median of the dry_bulb_faren column
# ----> 2 print(df_clean['dry_bulb_faren'].median())
#       3
#       4 # Print the median of the dry_bulb_faren column for the time range '2011-Apr':'2011-Jun'
#       5 print(df_clean.loc['2011-Apr':'2011-Jun', 'dry_bulb_faren'].median())
#
# NameError: name 'df_clean' is not defined

# %%
df_clean.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-1fe30c59f4d5> in <module>
# ----> 1 df_clean.dtypes
#
# NameError: name 'df_clean' is not defined

# %%
df_climate = pd.read_csv('weather_data_austin_2010.csv', parse_dates = True, index_col = 'Date')
df_climate.head()
# Out:
#                      Temperature  DewPoint  Pressure
# Date
# 2010-01-01 00:00:00         46.2      37.5       1.0
# 2010-01-01 01:00:00         44.6      37.1       1.0
# 2010-01-01 02:00:00         44.1      36.9       1.0
# 2010-01-01 03:00:00         43.8      36.9       1.0
# 2010-01-01 04:00:00         43.5      36.8       1.0

# %%
# Downsample df_clean by day and aggregate by mean: daily_mean_2011
daily_mean_2011 = df_clean.resample('D').mean()

# Extract the dry_bulb_faren column from daily_mean_2011 using .values: daily_temp_2011
daily_temp_2011 = daily_mean_2011['dry_bulb_faren'].values

# Downsample df_climate by day and aggregate by mean: daily_climate
daily_climate = df_climate.resample('D').mean()

# Extract the Temperature column from daily_climate using .reset_index(): daily_temp_climate
daily_temp_climate = daily_climate.reset_index()['Temperature']

# Compute the difference between the two arrays and print the mean difference
difference = daily_temp_2011 - daily_temp_climate
difference.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-f733b9bd9d11> in <module>
#       1 # Downsample df_clean by day and aggregate by mean: daily_mean_2011
# ----> 2 daily_mean_2011 = df_clean.resample('D').mean()
#       3
#       4 # Extract the dry_bulb_faren column from daily_mean_2011 using .values: daily_temp_2011
#       5 daily_temp_2011 = daily_mean_2011['dry_bulb_faren'].values
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# ### Sunny or cloudy

# %%
# Using df_clean, when is sky_condition 'CLR'?
is_sky_clear = df_clean['sky_condition']=='CLR'

# Filter df_clean using is_sky_clear
sunny = df_clean[is_sky_clear]

# Resample sunny by day then calculate the max
sunny_daily_max = sunny.resample('D').max()

# See the result
sunny_daily_max.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-28999fc7528c> in <module>
#       1 # Using df_clean, when is sky_condition 'CLR'?
# ----> 2 is_sky_clear = df_clean['sky_condition']=='CLR'
#       3
#       4 # Filter df_clean using is_sky_clear
#       5 sunny = df_clean[is_sky_clear]
#
# NameError: name 'df_clean' is not defined

# %%
# Using df_clean, when does sky_condition contain 'OVC'?
is_sky_overcast = df_clean['sky_condition'].str.contains('OVC')

# Filter df_clean using is_sky_overcast
overcast = df_clean[is_sky_overcast]

# Resample overcast by day then calculate the max
overcast_daily_max = overcast.resample('D').max()

# See the result
overcast_daily_max.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-46c0f6cbba00> in <module>
#       1 # Using df_clean, when does sky_condition contain 'OVC'?
# ----> 2 is_sky_overcast = df_clean['sky_condition'].str.contains('OVC')
#       3
#       4 # Filter df_clean using is_sky_overcast
#       5 overcast = df_clean[is_sky_overcast]
#
# NameError: name 'df_clean' is not defined

# %%
# Calculate the mean of sunny_daily_max
sunny_daily_max_mean = sunny_daily_max.mean()

# Calculate the mean of overcast_daily_max
overcast_daily_max_mean = overcast_daily_max.mean()

# Print the difference (sunny minus overcast)
print(sunny_daily_max_mean - overcast_daily_max_mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-519f805c9b9e> in <module>
#       1 # Calculate the mean of sunny_daily_max
# ----> 2 sunny_daily_max_mean = sunny_daily_max.mean()
#       3
#       4 # Calculate the mean of overcast_daily_max
#       5 overcast_daily_max_mean = overcast_daily_max.mean()
#
# NameError: name 'sunny_daily_max' is not defined

# %% [markdown]
# ### Weekly average temperature and wind speed

# %%
# Select the visibility and dry_bulb_faren columns and resample them: weekly_mean
weekly_mean =df_clean[['wind_speed', 'dry_bulb_faren']].resample('W').mean()

# Print the output of weekly_mean.corr()
print(weekly_mean.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-b23eb52b34a4> in <module>
#       1 # Select the visibility and dry_bulb_faren columns and resample them: weekly_mean
# ----> 2 weekly_mean =df_clean[['wind_speed', 'dry_bulb_faren']].resample('W').mean()
#       3
#       4 # Print the output of weekly_mean.corr()
#       5 print(weekly_mean.corr())
#
# NameError: name 'df_clean' is not defined

# %%
# Plot weekly_mean with subplots=True
weekly_mean.plot(subplots=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-60654db47caa> in <module>
#       1 # Plot weekly_mean with subplots=True
# ----> 2 weekly_mean.plot(subplots=True)
#       3 plt.show()
#
# NameError: name 'weekly_mean' is not defined

# %% [markdown]
# ### Daily hours of clear sky

# %%
is_sky_clear = df_clean['sky_condition'] == 'CLR'
resampled = is_sky_clear.resample('D')
sunny_hours = resampled.sum()
total_hours = resampled.count()
sunny_fraction = sunny_hours / total_hours

# Make a box plot of sunny_fraction
sunny_fraction.plot(kind='box')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-50925a0bf5cb> in <module>
# ----> 1 is_sky_clear = df_clean['sky_condition'] == 'CLR'
#       2 resampled = is_sky_clear.resample('D')
#       3 sunny_hours = resampled.sum()
#       4 total_hours = resampled.count()
#       5 sunny_fraction = sunny_hours / total_hours
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# ### Heat or humidity

# %%
# Resample dew_point_faren and dry_bulb_faren by Month, aggregating the maximum values: monthly_max
monthly_max = df_clean[['dew_point_faren','dry_bulb_faren']].resample('M').max()

# Generate a histogram with bins=8, alpha=0.5, subplots=True
monthly_max.plot(kind = 'hist', bins = 8, alpha = 0.5, subplots = True)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-58611a998355> in <module>
#       1 # Resample dew_point_faren and dry_bulb_faren by Month, aggregating the maximum values: monthly_max
# ----> 2 monthly_max = df_clean[['dew_point_faren','dry_bulb_faren']].resample('M').max()
#       3
#       4 # Generate a histogram with bins=8, alpha=0.5, subplots=True
#       5 monthly_max.plot(kind = 'hist', bins = 8, alpha = 0.5, subplots = True)
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# ### Probability of high temperatures

# %%
# Extract the maximum temperature in August 2010 from df_climate: august_max
august_max = df_climate.loc['2010-Aug','Temperature'].max()
print(august_max)

# Resample August 2011 temps in df_clean by day & aggregate the max value: august_2011
august_2011 = df_clean.loc['2011-Aug','dry_bulb_faren'].resample('D').max()

# Filter for days in august_2011 where the value exceeds august_max: august_2011_high

august_2011_high = august_2011.loc[august_2011 > august_max]

# Construct a CDF of august_2011_high
august_2011_high.plot(kind='hist', density=True, cumulative=True, bins=25)

# Display the plot
plt.show()
# Out:
# 95.3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-5edb55518259> in <module>
#       4
#       5 # Resample August 2011 temps in df_clean by day & aggregate the max value: august_2011
# ----> 6 august_2011 = df_clean.loc['2011-Aug','dry_bulb_faren'].resample('D').max()
#       7
#       8 # Filter for days in august_2011 where the value exceeds august_max: august_2011_high
#
# NameError: name 'df_clean' is not defined
